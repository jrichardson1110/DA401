# %%
import import_ipynb
import SubwayDesign
import DataReading
import geopy.distance
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
from itertools import combinations, permutations
import folium
import csv

# %%
#Producing the Columbus map

columbus_ids, columbus_block_populations, columbus_latitudes, columbus_longitudes = DataReading.dataReading("ColumbusCensusBlockPopulations.csv", ", Franklin County, Ohio", "049",
           "OhioGeodata.csv")

columbus_all_stations = DataReading.all_stations_creation(columbus_ids, columbus_block_populations, columbus_latitudes, columbus_longitudes)

columbus_nearbyList = DataReading.nearbyListCreation(columbus_all_stations)

columbusMandatoryPoints = [(39.998345806129954,-82.88979884336064), #Airport
                           (39.96850270609502,-83.0108044487167), #Columbus Clippers stadium
                           (39.968367048806286,-83.01687515364868), #Columbus Crew stadium
                          (39.96926572311619,-83.00587578097635), #Columbus Blue Jackets stadium
                          (39.96130794186046,-82.99907950882992), #Ohio statehouse (central business district landmark)
                          (39.95965647233419,-83.0069949197098), #COSI
                          (39.96377353750112,-82.98706223485121), #Discovery district
                          (39.95047595380575,-82.99837029153437)] #Beck st and S High st (German village/Brewery district)

columbus_points_selected, columbus_num_people_reached = SubwayDesign.point_selection(columbus_all_stations, columbus_nearbyList, 25, columbusMandatoryPoints)

columbus_station_indexes, columbus_points_selected_df, columbus_distances = SubwayDesign.station_mapping(columbus_points_selected, columbus_all_stations)
        
map, columbus_mileage = SubwayDesign.routeOptimization(columbus_station_indexes, columbus_points_selected_df, columbus_distances)

map

# %%
#Producing the Cleveland map

cleveland_ids, cleveland_block_populations, cleveland_latitudes, cleveland_longitudes = DataReading.dataReading("ClevelandCensusBlockPopulations.csv", ", Cuyahoga County, Ohio", "035",
           "OhioGeodata.csv")

cleveland_all_stations = DataReading.all_stations_creation(cleveland_ids, cleveland_block_populations, cleveland_latitudes, cleveland_longitudes)

cleveland_nearbyList = DataReading.nearbyListCreation(cleveland_all_stations)

clevelandMandatoryPoints = [(41.411128997802734,-81.8383560180664), #Airport
                          (41.506031, -81.699578), #Browns stadium
                          (41.496055, -81.685311), #Guardians stadium
                           (41.496665, -81.688225), #Rocket Mortgage Fieldhouse (Cavaliers arena)
                            (41.5084983,-81.6954068), #Rock and roll hall of fame
                           (41.49684822082334,-81.694074350589), #Tower city center
                            (41.500053025340634,-81.7053338607223), #The flats
                            (41.503907531124845,-81.69003859184342)] #9th st and st claire ave (central business district)

cleveland_points_selected, cleveland_num_people_reached = SubwayDesign.point_selection(cleveland_all_stations, cleveland_nearbyList, 21, clevelandMandatoryPoints)

cleveland_station_indexes, cleveland_points_selected_df, cleveland_distances = SubwayDesign.station_mapping(cleveland_points_selected, cleveland_all_stations)
        
map, cleveland_mileage = SubwayDesign.routeOptimization(cleveland_station_indexes, cleveland_points_selected_df, cleveland_distances)

map

# %%
#Seeing what populations surround the actual lines in Cleveland

real_cleveland_redline_stations = [
    (41.41042155107532, -81.83779832064992), #Airport
    (41.41948804165519, -81.82582879852285), #Brookpark
    (41.4413579171038, -81.80727047801535), #Puritas
    (41.4569899468165, -81.79377464371102), #West Park
    (41.466347822137045, -81.78602680455693), #Triskett
    (41.476021421061475, -81.76842000302175), #West 117th – Madison
    (41.48032049263017, -81.75209929983109), #West Blvd-Cudell Station
    (41.476387951812924, -81.72921679949138), #W.65-Lorain Station
    (41.48492526145388, -81.70367324632512), #W.25-Ohio City Station
    (41.497423966786066, -81.69564512309988), #Tower City – Public Square
    (41.48666461260769, -81.66750733857204), #East 34th – Campus
    (41.48075888766412, -81.65289101866017), #East 55th
    (41.48580025342287, -81.6340013173604), #East 79th
    (41.49355316737867, -81.61778765668204), #East 105th – Quincy
    (41.4998609374566, -81.6077918562811), #Cedar – University
    (41.50884992201369, -81.60208559218425), #Little Italy – University Circle
    (41.52320023799339, -81.59303427669184), #Superior
    (41.53061072576907, -81.58888285489502)] #Windermere (Louis Stokes Station)

    
cleveland_red_line_pop = SubwayDesign.existingStationPopulations(real_cleveland_redline_stations, cleveland_all_stations)

real_cleveland_blueline_stations = [
    (41.50929687239099, -81.68888608033242), #South Harbor
    (41.50665097903719, -81.69400945588978), #North Coast
    (41.50406261777134, -81.69926438633019), #W 3rd St
    (41.49953588022658, -81.70391855645204), #Flats East Bank
    (41.49636674010069, -81.70051715800207), #Settlers Landing
    (41.4975278159535, -81.69449576743797), #Tower City – Public Square
    (41.48661182151873, -81.66645630297579), #East 34th – Campus
    (41.4806982291537, -81.65183654578514), #East 55th
    (41.48064104471174, -81.63323182418901), #East 79th
    (41.48272291513051, -81.61886509177266), #Woodhill
    (41.48408810234312, -81.60395354393745), #East 116th
    (41.483845373912224, -81.5921037224904), #Shaker Square
    (41.48236894957266, -81.58847031623523), #Drexmore
    (41.47891074724204, -81.58500853858091), #South woodland
    (41.47559887377586, -81.5811965837048), #Southington
    (41.47222193221492, -81.57761720092395), #Onaway
    (41.46857445550034, -81.57290133610006), #Ashby
    (41.46658952049858, -81.5664306135471), #Lee
    (41.466513637042866, -81.56016220296051), #Avalon
    (41.46653720364958, -81.55410509480029), #Kenmore
    (41.466635852088, -81.54672275029363), #Lynnfield
    (41.46659791040571, -81.54078851995891), #Farnsleigh
    (41.466021193999566, -81.53764925148266)] #Warrensville–Van Aken
    
cleveland_blue_line_pop = SubwayDesign.existingStationPopulations(real_cleveland_blueline_stations, cleveland_all_stations)

print(cleveland_red_line_pop)
print(cleveland_blue_line_pop)

# %%
#Producing the Pittsburgh map

pittsburgh_ids, pittsburgh_block_populations, pittsburgh_latitudes, pittsburgh_longitudes = DataReading.dataReading("PittsburghCensusBlockPopulations.csv", ", Allegheny County, Pennsylvania", "003",
           "PennsylvaniaGeodata.csv")

pittsburgh_all_stations = DataReading.all_stations_creation(pittsburgh_ids, pittsburgh_block_populations, pittsburgh_latitudes, pittsburgh_longitudes)

pittsburgh_nearbyList = DataReading.nearbyListCreation(pittsburgh_all_stations)

pittsburghMandatoryPoints = [(40.44686951094768, -80.01645040752037), #Steelers stadium
                          (40.44757793881872, -80.00691260317441), #Pirates stadium
                          (40.43938535973304, -79.9901399766658), #Penguins arena
                          (40.42876760175547, -79.98055386479753), #South side
                          (40.440878470912786, -80.00286595488159), #Market square (downtown public space)
                          (40.43939502934492, -79.99679676694929), #Big intersection of central business district
                            (40.44334637543695, -79.95016480181377), #Museum of natural history
                             (40.45100052292829, -79.9856931811249)] #Strip district

pittsburgh_points_selected, pittsburgh_num_people_reached = point_selection(pittsburgh_all_stations, pittsburgh_nearbyList, 29, pittsburghMandatoryPoints)

pittsburgh_station_indexes, pittsburgh_points_selected_df, pittsburgh_distances = station_mapping(pittsburgh_points_selected, pittsburgh_all_stations)
        
map, pittsburgh_mileage = routeOptimization(pittsburgh_station_indexes, pittsburgh_points_selected_df, pittsburgh_distances)

map

# %%
print("Columbus population reached: ", columbus_num_people_reached)
print("Cleveland population reached: ", cleveland_num_people_reached)
print("Columbus total track mileage: ", columbus_mileage)
print("Cleveland total track mileage: ", cleveland_mileage)

# %%
#Producing the Pittsburgh map

pittsburghMandatoryPoints = [(40.44686951094768, -80.01645040752037), #Steelers stadium
                          (40.44757793881872, -80.00691260317441), #Pirates stadium
                          (40.43938535973304, -79.9901399766658), #Penguins arena
                          (40.42876760175547, -79.98055386479753), #South side
                          (40.440878470912786, -80.00286595488159), #Market square (downtown public space)
                          (40.43939502934492, -79.99679676694929), #Big intersection of central business district
                            (40.44334637543695, -79.95016480181377), #Museum of natural history
                             (40.45100052292829, -79.9856931811249)] #Strip district

pittsburgh_points_selected, pittsburgh_num_people_reached = point_selection(pittsburgh_all_stations, pittsburgh_nearbyList, 22, pittsburghMandatoryPoints)

pittsburgh_station_indexes, pittsburgh_points_selected_df, pittsburgh_distances = station_mapping(pittsburgh_points_selected, pittsburgh_all_stations)
        
map, pittsburgh_mileage = routeOptimization(pittsburgh_station_indexes, pittsburgh_points_selected_df, pittsburgh_distances)

map

# %%
#Seeing what populations surround the actual lines in Pittsburgh

real_pittsburgh_redline_stations = [(40.339404030996256, -80.05366531785246), #South Hills Village
                                    (40.340152370166436, -80.04862168309737), #Dorchester
                                    (40.34436142807127, -80.04666975760124), #Bethel Village
                                    (40.34839501360049, -80.03992599347887), #Highland
                                    (40.34922706031375, -80.03428869392933), #Casswell
                                    (40.353593622638606, -80.02841865923983), #Washington Junction
                                    (40.35675504547715, -80.02936858876406), #Smith Road
                                    (40.36090731327373, -80.02949766219598), #St Anne's
                                    (40.3658910830015, -80.02733552096265), #Overbrook Junction
                                    (40.36816312184608, -80.030502166598), #Castle Shannon
                                    (40.36989228949163, -80.03337293191935), #Arlington
                                    (40.37539039587903, -80.03859947646363), #Poplar
                                    (40.3822747527622, -80.04338566076963), #Mount Lebanon
                                    (40.392001875467756, -80.04095434985521), #Dormont Junction
                                    (40.397346445953225, -80.0366813325531), #Potomac
                                    (40.39949791307168, -80.03377103999316), #Stevenson
                                    (40.40408207917509, -80.03033705358291), #Broadway Ave/Shiras
                                    (40.4070033532357, -80.02728229884382), #Broadway Ave/Belasco
                                    (40.410361543951474, -80.02478357128446), #Broadway Ave/Hampshire
                                    (40.411211089815794, -80.02348698773703), #Fallowfield
                                    (40.41030015661679, -80.02013124007709), #Westfield
                                    (40.41298096012369, -80.01102137498283), #Dawn
                                    (40.41640626254351, -80.01163589246764), #Palm Garden
                                    (40.42083833980938, -80.00754938419435), #South Hills Junction Station
                                    (40.43155536632183, -80.00316923485636), #Station Square Station
                                    (40.4355580908441, -79.9968221304218), #First Avenue Station
                                    (40.43980952213997, -79.99599147154893), #Steel Plaza Station
                                    (40.44234398225842, -79.99982768036222), #Wood Street Station
                                    (40.44176668380782, -80.00435868160436), #Gateway
                                    (40.44792397026633, -80.00934543174424), #North Side
                                    (40.44786827703521, -80.01866239504406)] #Allegheny Station

pittsburgh_red_line_pop = SubwayDesign.existingStationPopulations(real_pittsburgh_redline_stations, pittsburgh_all_stations)


real_pittsburgh_silverline_stations = [(40.28704374712206, -80.0209057821801), #Library Station
                                       (40.29412980948608, -80.02998668830698), #West Library
                                       (40.29646565710603, -80.03054030753675), #Sandy Creek
                                       (40.30091260141285, -80.03159076588541), #Beagle
                                       (40.308015196311494, -80.033483220025), #Kings School Road
                                       (40.3117427076363, -80.03325279783986), #Logan Road
                                       (40.31561187353976, -80.03011239101825), #Sarah
                                       (40.32281536003744, -80.02978771578361), #Munroe
                                       (40.32812071458039, -80.03075243151046), #South Park Road
                                       (40.330801754156944, -80.03093450556042), #Mesta
                                       (40.334473780556905, -80.03138430551864), #Lytle
                                       (40.34548339028499, -80.02900293524404), #Hillcrest
                                       (40.353593622638606, -80.02841865923983), #Washington Junction
                                        (40.35675504547715, -80.02936858876406), #Smith Road
                                        (40.36090731327373, -80.02949766219598), #St Anne's
                                        (40.36535314592413, -80.02672023536495), #Willow Station
                                        (40.36647877368758, -80.01684356734592), #Memorial Hall
                                        (40.37371872325824, -80.00818224186047), #Killarney
                                        (40.37799029247101, -80.0047867923195), #McNeilly Station
                                        (40.39263789534187, -79.99840067632336), #South Bank Station
                                        (40.399620735519534, -79.9993552614625), #Denise Station
                                        (40.40794585694221, -80.00327430220862), #Bon Air Station
                                        (40.416695370180854, -80.01069940626388), #Boggs Station
                                        (40.42083833980938, -80.00754938419435), #South Hills Junction Station
                                        (40.43155536632183, -80.00316923485636), #Station Square Station
                                        (40.4355580908441, -79.9968221304218), #First Avenue Station
                                        (40.43980952213997, -79.99599147154893), #Steel Plaza Station
                                        (40.44234398225842, -79.99982768036222), #Wood Street Station
                                        (40.44176668380782, -80.00435868160436), #Gateway
                                        (40.44792397026633, -80.00934543174424), #North Side
                                        (40.44786827703521, -80.01866239504406)] #Allegheny Station

pittsburgh_silver_line_pop = SubwayDesign.existingStationPopulations(real_pittsburgh_silverline_stations, pittsburgh_all_stations)

print(pittsburgh_red_line_pop)
print(pittsburgh_silver_line_pop)
